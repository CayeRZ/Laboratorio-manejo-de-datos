# %%
print("hola mundo")
# Out:
# hola mundo

# %%
# !pip install mysql-connector-python pandas
# Out:
# Collecting mysql-connector-python
#   Downloading mysql_connector_python-9.7.0-cp313-cp313-macosx_14_0_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading mysql_connector_python-9.7.0-cp313-cp313-macosx_14_0_x86_64.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 1.0 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: mysql-connector-python
# Successfully installed mysql-connector-python-9.7.0

# %%
import mysql.connector

try:
    # 1. Establecer conexión
    conexion = mysql.connector.connect(
        host="127.0.0.1",
        port="10101",
        user="root",          # Usuario por defecto en XAMPP/WAMP
        password="admin123",          # Suele estar vacío por defecto localmente
        database="pia_data_01"
    )

    if conexion.is_connected():
        print("Conectado exitosamente a MySQL")
        
        # 2. Consultar datos
        consulta = "SELECT * FROM pia_data_01"
        df = pd.read_sql(consulta, conexion)
        display(df)

except mysql.connector.Error as e:
    print(f"Error al conectar: {e}")
finally:
    # 3. Cerrar conexión
    if 'conexion' in locals() and conexion.is_connected():
        conexion.close()
# Out:
# Conectado exitosamente a MySQL
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 18
#      16         # 2. Consultar datos
#      17         consulta = "SELECT * FROM pia_data_01"
# ---> 18         df = pd.read_sql(consulta, conexion)
#      19         display(df)
#      21 except mysql.connector.Error as e:
#
# NameError: name 'pd' is not defined
